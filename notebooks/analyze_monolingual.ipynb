# %%
# %cd /mnt/storage/maxenis/coptic-machine-translation
# Out:
# /mnt/storage/maxenis/coptic-machine-translation

# %%
import pandas as pd

# %%
mono = pd.read_csv('datasets/monolingual_data_norm_romanized_translated.csv')

print(list(mono["meta::title"].unique()))
text = ['Life of Longinus and Lucius part 1', 'Life of Longinus and Lucius part 2', 'Life of Longinus and Lucius part 3']
for text in [text1, text2, text3]:
    display(f"Translation of {text}:")
    display(" ".join (list(mono[mono["meta::title"] == text]["eng"])))
# Out:
# ['Apa Johannes Canons: FA143-158', 'Apa Johannes Canons: FA191-192', 'Apa Johannes Canons: FA203-204', 'Apa Johannes Canons: MONB.FA 205-214', 'Apa Johannes Canons: MONB.FA 215-224', 'Apa Johannes Canons: MONB.FA 225-232', 'Apa Johannes Canons: MONB.FA 233-240', 'Apa Johannes Canons: MONB.FA 241-252', 'Apa Johannes Canons: FA253-255', 'Apa Johannes Canons: MONB.FA 29-30', 'Apa Johannes Canons: MONB.FA [33]-[34]', 'Apa Johannes Canons: MONB.FA [37]-42', 'Apa Johannes Canons: FA[47]-[48]', 'Apa Johannes Canons: FA65-80', 'Life of Apa Aphou part 1', 'Life of Apa Aphou part 2', 'Life of Longinus and Lucius part 1', 'Life of Longinus and Lucius part 2', 'Life of Longinus and Lucius part 3', 'Life of Longinus and Lucius part 4', 'Life of Longinus and Lucius part 5', 'Life of Paul of Tamma part 1', 'Life of Paul of Tamma part 2', 'Life of Apa Phib part 1', 'Life of Apa Phib part 2', 'Life of Pisentius part 3', 'Pistis Sophia Postscript', 'Pistis Sophia Book 1 Part 3', 'Pistis Sophia Book 1 
# ...

# %%
data = pd.read_csv("datasets/train_data/data.csv")
print(list(data["meta::title"].unique()))
text = "Pistis Sophia Book 1 Part 2"
list(data[data["meta::title"].str.contains("'My Heart Is Crushed")]["eng"])
# Out:
# ['Apophthegmata Patrum Sahidic 001: Anonymous Nau 135', 'Apophthegmata Patrum Sahidic 002: Anonymous Nau 136', 'Apophthegmata Patrum Sahidic 003: Anonymous Nau 138', 'Apophthegmata Patrum Sahidic 004: Poemen', 'Apophthegmata Patrum Sahidic 005', 'Apophthegmata Patrum Sahidic 006: anonymous Nau 196', 'Apophthegmata Patrum Sahidic 007', 'Apophthegmata Patrum Sahidic 008', 'Apopthegmata Patrum Sahidic 009: Hyperechius 2', 'Apophthegmata Patrum Sahidic 014', 'Apophthegmata Patrum Sahidic 017', 'Apophthegmata Patrum Sahidic 018: Anonymous', 'Apophthegmata Patrum Sahidic 019: Presbyter', 'Apophthegmata Patrum Sahidic 020: Failings', 'Apophthegmata Patrum Sahidic 021: Lentils', 'Apophthegmata Patrum Sahidic 022: fragment', 'Apophthegmata Patrum Sahidic 024: Isaac', 'Apophthegmata Patrum Sahidic 026: Cassian 7 (68)', 'Apophthegmata Patrum Sahidic 027: Pistamon 1', 'Apophthegmata Patrum Sahidic 028', 'Apophthegmata Patrum Sahidic 029', 'Apophthegmata Patrum Sahidic 030', 'Apophthegmata Patrum
# ...
